# %%
#why do we need visualisation? summarisation of data
#matplotlib, seaborn, plotly, bokeh
#matplotlib>> Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python. Matplotlib makes easy things easy and hard things possible.

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting matplotlib
#   Downloading matplotlib-3.9.0-cp39-cp39-macosx_11_0_arm64.whl (7.8 MB)
#      |████████████████████████████████| 7.8 MB 2.4 MB/s eta 0:00:01
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.53.0-cp39-cp39-macosx_11_0_arm64.whl (2.2 MB)
#      |████████████████████████████████| 2.2 MB 12.6 MB/s eta 0:00:01
# Requirement already satisfied: packaging>=20.0 in /Users/shaikyasin/Library/Python/3.9/lib/python/site-packages (from matplotlib) (24.0)
# Requirement already satisfied: numpy>=1.23 in /Users/shaikyasin/Library/Python/3.9/lib/python/site-packages (from matplotlib) (1.26.4)
# Collecting importlib-resources>=3.2.0
#   Downloading importlib_resources-6.4.0-py3-none-any.whl (38 kB)
# Collecting pyparsing>=2.3.1
#   Downloading pyparsing-3.1.2-py3-none-any.whl (103 kB)
#      |████████████████████████████████| 103 kB 14.7 MB/s eta 0:00:01
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.5-cp39-cp39-macosx_11_0_arm64.whl (66 kB)
#      |████████████████████████████████| 66 kB 13.1 MB/s eta 0:00:01
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.2.1-cp39-cp39-macosx_11_0_arm64.whl (244 kB)
#      |████████████████████████████████| 244 kB 4.3 MB/s eta 0:00:01
# Collecting pillow>=8
#   Downloading pillow-10.3.0-cp39-cp39-macosx_11_0_arm64.whl (3.4 MB)
#      |████████████████████████████████| 3.4 MB 8.7 MB/s eta 0:00:01
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/shaikyasin/Library/Python/3.9/lib/python/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/shaikyasin/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.19.0)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.15.0)
# Installing collected packages: pyparsing, pillow, kiwisolver, importlib-resources, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.2.1 cycler-0.12.1 fonttools-4.53.0 importlib-resources-6.4.0 kiwisolver-1.4.5 matplotlib-3.9.0 pillow-10.3.0 pyparsing-3.1.2
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#bar, hist, scatter plot, pie chart, line

# %%
x = np.random.rand(50)
y = np.random.rand(50)

# %%
x
# Out:
# array([0.46674483, 0.77770496, 0.62185906, 0.15278498, 0.16295784,
#        0.93516771, 0.88498172, 0.6878345 , 0.39959475, 0.26490402,
#        0.98787597, 0.5966899 , 0.4007468 , 0.91493785, 0.15188418,
#        0.40598419, 0.2026722 , 0.88053423, 0.92004798, 0.14087426,
#        0.65415622, 0.20092705, 0.33195489, 0.77786164, 0.04997851,
#        0.50051836, 0.19538534, 0.92079906, 0.93541383, 0.80030042,
#        0.1906639 , 0.61101524, 0.57094555, 0.90829434, 0.99216346,
#        0.75671474, 0.19538631, 0.64482606, 0.31203441, 0.64390877,
#        0.13172803, 0.90198699, 0.30607939, 0.19763204, 0.75369176,
#        0.18975988, 0.26370018, 0.90020398, 0.81256858, 0.95413482])

# %%
y
# Out:
# array([3.94395751e-01, 9.88085735e-02, 5.04488151e-01, 4.94008616e-01,
#        8.69447377e-01, 6.53593146e-01, 3.40699526e-01, 7.41278721e-01,
#        1.77312402e-01, 6.84442910e-01, 5.61415914e-01, 5.63938727e-01,
#        4.60792609e-01, 8.32787082e-02, 7.04362390e-01, 3.80208799e-01,
#        8.69816740e-01, 8.17654527e-01, 9.54238413e-01, 3.84983822e-01,
#        3.65721126e-01, 5.72055612e-01, 8.87241306e-01, 3.27442217e-01,
#        2.28216882e-01, 7.55564049e-01, 9.00710080e-01, 8.55378374e-01,
#        3.28490100e-01, 5.38493789e-01, 2.40979741e-01, 6.07920521e-01,
#        4.30375216e-01, 9.48916520e-04, 6.29330893e-01, 9.95511320e-01,
#        4.98136336e-01, 7.32728164e-01, 9.36738549e-01, 4.07932115e-01,
#        4.43854009e-01, 1.70721499e-01, 5.47748947e-01, 9.41424298e-01,
#        4.95773298e-01, 1.52883082e-01, 7.64928815e-01, 5.06020300e-01,
#        2.06337020e-01, 2.57229622e-01])

# %%
plt.scatter(x,y) #To understand the relationship between two variables

# %%
df = pd.DataFrame(np.random.randn(1000), columns = ['data'], index = pd.date_range('2024-03-29', periods =1000))

# %%
df
# Out:
#                 data
# 2024-03-29  0.099751
# 2024-03-30  0.024164
# 2024-03-31 -1.035980
# 2024-04-01 -0.305961
# 2024-04-02 -0.279197
# ...              ...
# 2026-12-19  0.354210
# 2026-12-20 -1.282854
# 2026-12-21  0.061145
# 2026-12-22  1.303776
# 2026-12-23  1.418325
#
# [1000 rows x 1 columns]

# %%
df.plot(figsize = (20, 8))
# Out:
# <Axes: >

# %%
#line plot
#whenever time component is involved on x axis
#depict the relation between two variables in the trend


x = [1, 2, 3, 4, 5]
y = [5, 1, 7, 8, 2]

plt.plot(x, y)

# %%
plt.plot(x, y)
plt.title("line plot to understand the syntax")
plt.xlabel("x points")
plt.ylabel("y points")
plt.show()

# %%
plt.plot(x, y, color = "red")
plt.title("line plot to understand the syntax")
plt.xlabel("x points")
plt.ylabel("y points")
plt.show()

# %%
plt.plot(x, y, color = "red", marker = "o")
plt.title("line plot to understand the syntax")
plt.xlabel("x points")
plt.ylabel("y points")
plt.show()

# %%
plt.plot(x, y, color = "red", marker = "o", linestyle = '--')
plt.title("line plot to understand the syntax")
plt.xlabel("x points")
plt.ylabel("y points")
plt.show()

# %%
plt.plot(x, y, color = "red", marker = "o", linestyle = '--', linewidth = 3)
plt.title("line plot to understand the syntax")
plt.xlabel("x points")
plt.ylabel("y points")
plt.show()

# %%
plt.plot(x, y, color = "red", marker = "o", linestyle = '--', linewidth = 3, markersize=10)
plt.title("line plot to understand the syntax")
plt.xlabel("x points")
plt.ylabel("y points")
plt.show()

# %%
plt.plot(x, y, color = "red", marker = "o", linestyle = '--', linewidth = 3, markersize=10)
plt.title("line plot to understand the syntax")
plt.xlabel("x points")
plt.ylabel("y points")
plt.grid()
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y1 = [5, 1, 7, 8, 2]
y2 = [7, 8, 3, 5, 1]


plt.plot(x, y1, color = "red", marker = "o", linestyle = '--', linewidth = 3, markersize=6, label = 'line y1')
plt.plot(x, y2, color = "b", marker = "o", linestyle = '--', linewidth = 3, markersize=10, label = 'line y2')

plt.xlabel("x data axis")
plt.ylabel("y data axis")

plt.title("Multiple lines in one plot")
plt.legend()

plt.show()

# %%
x = np.linspace(0, 10, 100)

# %%
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
#         6.56565657,  6.66666667,  6.76767677,  6.86868687,  6.96969697,
#         7.07070707,  7.17171717,  7.27272727,  7.37373737,  7.47474747,
#         7.57575758,  7.67676768,  7.77777778,  7.87878788,  7.97979798,
#         8.08080808,  8.18181818,  8.28282828,  8.38383838,  8.48484848,
#         8.58585859,  8.68686869,  8.78787879,  8.88888889,  8.98989899,
#         9.09090909,  9.19191919,  9.29292929,  9.39393939,  9.49494949,
#         9.5959596 ,  9.6969697 ,  9.7979798 ,  9.8989899 , 10.        ])

# %%
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))

# %%
plt.plot(x, np.sin(x), '--')

# %%
plt.plot(x, np.sin(x), '-')

# %%
plt.plot(x, np.sin(x), '.-')

# %%
plt.plot(x, np.sin(x), ':')

# %%
plt.figure()
plt.subplot(1, 2, 1)
plt.plot(x, np.sin(x))


plt.subplot(1, 2, 2)
plt.plot(x, np.cos(x))

plt.show()

# %%
plt.figure()
plt.subplot(2, 2, 1)
plt.plot(x, np.sin(x))


plt.subplot(2, 2, 2)
plt.plot(x, np.cos(x))

plt.subplot(2, 2, 3)
plt.plot(x, np.tan(x))

plt.subplot(2, 2, 4)
plt.plot(x, np.cos(x+1))

plt.show()

# %%
plt.figure()
plt.subplot(2, 1, 1)
plt.plot(x, np.sin(x))


plt.subplot(2, 1, 2)
plt.plot(x, np.cos(x))


plt.show()

# %%
plt.plot(x, np.sin(x-0), color = "blue")

# %%
plt.plot(x, np.sin(x-0), color = 'blue')
plt.ylim(-1.5, 1.5)
plt.xlim(1, 15)
plt.show()

# %%
plt.plot(x, np.sin(x-0), color = 'blue')
plt.ylim(-1.5, 1.5)
plt.xlim(1, 15)
plt.axis('equal')
plt.show()

# %%
plt.plot(x, np.sin(x-0), color = 'blue')
plt.ylim(-1.5, 1.5)
plt.xlim(1, 15)
plt.grid()
plt.show()

# %%
plt.plot(x, np.sin(x-0), color = 'blue')
plt.ylim(-1.5, 1.5)
plt.xlim(1, 15)

plt.title("basic syntax")
plt.xlabel("x label")
plt.ylabel("y label")
plt.axis('equal')
plt.grid()
plt.show()

# %%
#histogram>> continuous/numerical data distribution


data = np.random.randn(1000) #10 bins
plt.hist(data, color='r', bins = 20)
plt.show()

# %%
#stacked histogram


data1 = np.random.normal(0, 1, 5000)
data2 = np.random.normal(3, 2, 5000)

# %%
data1
# Out:
# array([-1.17427945,  0.77854523,  0.57959984, ...,  0.03983732,
#        -1.63002371,  0.36955705])

# %%
data2
# Out:
# array([5.50785875, 2.67846394, 1.98688935, ..., 2.10251567, 3.17721821,
#        5.20684988])

# %%
plt.hist([data1, data2], bins = 20, color = ['r', 'b'], label = ['dist1', 'dist2'])
plt.xlabel('Values')
plt.ylabel('frequency')
plt.title("stacked histogram")
plt.show()

# %%
#scatter plot >> to understand the relationship between two features

x = np.random.rand(50)
y = np.random.rand(50)

# %%
x
# Out:
# array([0.64813295, 0.64202526, 0.61681643, 0.77102743, 0.26465269,
#        0.40941393, 0.49435982, 0.92304564, 0.12264333, 0.10634049,
#        0.89968286, 0.23476115, 0.61371863, 0.47788343, 0.29962883,
#        0.45689667, 0.48572728, 0.0340165 , 0.8305662 , 0.24520684,
#        0.16456254, 0.68823465, 0.69130829, 0.1802053 , 0.05476732,
#        0.05460422, 0.67869322, 0.19462034, 0.88347085, 0.59094005,
#        0.75429071, 0.10496752, 0.89209586, 0.60949251, 0.10534991,
#        0.75352714, 0.19573425, 0.50074898, 0.44060083, 0.83826177,
#        0.61787628, 0.22462861, 0.904503  , 0.51513923, 0.31405824,
#        0.98196802, 0.75185022, 0.18078604, 0.92158029, 0.11972716])

# %%
y
# Out:
# array([0.73628029, 0.93350491, 0.77590489, 0.63721264, 0.75411752,
#        0.40139712, 0.86567742, 0.54221147, 0.84532673, 0.07508125,
#        0.29065065, 0.04652769, 0.31512758, 0.02941756, 0.27077795,
#        0.55463391, 0.79813616, 0.48246958, 0.57747479, 0.0110198 ,
#        0.3438528 , 0.99638082, 0.68650073, 0.00694377, 0.56326857,
#        0.12456779, 0.72447737, 0.94472387, 0.24711335, 0.93426049,
#        0.23582489, 0.11543935, 0.29461797, 0.63413807, 0.44717649,
#        0.81923185, 0.94812136, 0.32611543, 0.2342843 , 0.98644988,
#        0.90539809, 0.5517196 , 0.47640142, 0.83080947, 0.97033525,
#        0.09754141, 0.73432982, 0.77801772, 0.33859637, 0.0578961 ])

# %%
plt.scatter(x, y, c = 'r', marker = 'X')

# %%
#bar plot >> To see the distribution of categorical variables

x = ['a', 'b', 'c', 'd']
y = [4, 6, 1, 2]


plt.bar(x, y, color = 'r')
# Out:
# <BarContainer object of 4 artists>

# %%
x = ['a', 'b', 'c', 'd']
y = [4, 6, 1, 2]


plt.barh(x, y, color = 'r')
# Out:
# <BarContainer object of 4 artists>

# %%
#pie chart >> To understand the percnt dist of data

langs = ['C', 'Python', 'Java']
students = [20, 100, 40]


plt.pie(students, labels = langs, autopct = '%1.1f%%')
plt.title("Pie chart")
plt.show()

# %%
explode = (0.0, 0.1, 0.1)

langs = ['C', 'Python', 'Java']
students = [20, 100, 40]


plt.pie(students, labels = langs, autopct = '%1.1f%%', explode = explode, shadow = True)
plt.title("Pie chart")
plt.show()

# %%
#3d plot

x = np.random.rand(20)
y = np.random.rand(20)
z = np.random.rand(20)


fig = plt.figure()
ax = fig.add_subplot(projection = '3d')
ax.scatter(x, y, z, c='red')

# %%
data = pd.read_csv("Bank_Churn.csv")
data
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
plt.scatter(x = data['Age'], y=data['Balance'])

# %%
data.plot.scatter(x = 'Age', y = 'Balance')
# Out:
# <Axes: xlabel='Age', ylabel='Balance'>

# %%
plt.hist(data['Age'], color='red')
# Out:
# (array([ 611., 2179., 3629., 1871.,  828.,  523.,  208.,  127.,   20.,
#            4.]),
#  array([18. , 25.4, 32.8, 40.2, 47.6, 55. , 62.4, 69.8, 77.2, 84.6, 92. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data['Balance'], color='red')
# Out:
# (array([3.623e+03, 6.900e+01, 3.600e+02, 1.173e+03, 2.081e+03, 1.747e+03,
#         7.290e+02, 1.860e+02, 3.000e+01, 2.000e+00]),
#  array([     0.   ,  25089.809,  50179.618,  75269.427, 100359.236,
#         125449.045, 150538.854, 175628.663, 200718.472, 225808.281,
#         250898.09 ]),
#  <BarContainer object of 10 artists>)

# %%
data.boxplot(column = 'Balance')
# Out:
# <Axes: >

# %%
plt.violinplot(data['Balance'])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x14e7225b0>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x14fba1fa0>,
#  'cmins': <matplotlib.collections.LineCollection at 0x14ed4cb80>,
#  'cbars': <matplotlib.collections.LineCollection at 0x14ed4c0d0>}

# %%
import matplotlib.pyplot as plt

# Sample data
years = [2021, 2018, 2022, 2023, 2017]
category1 = [20, 25, 30, 28, 35]
category2 = [10, 15, 20, 18, 25]
category3 = [5, 8, 10, 9, 15]

# Create a area plot
plt.stackplot(years, category1, category2, category3, labels=['Category 1', 'Category 2', 'Category 3'],
              colors=['skyblue', 'lightgreen', 'orange'])

# Add labels and title
plt.xlabel("Years")
plt.ylabel("Values")
plt.title("Area Plot")
plt.legend()

plt.show()
